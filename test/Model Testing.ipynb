# %% [markdown]
# ## *Required Libraries*

# %%
from keras.models import load_model
from keras.preprocessing.image import img_to_array,load_img
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## *Classes in Every Crop*

# %%
apple_classes=['Apple Scab', 'Black Rot', 'Cedar Apple Rust', 'Healthy']
cherry_classes=['Healthy', 'Powdery Mildew']
corn_classes=['Common Rust', 'Gray Leaf Spot', 'Healthy', 'Northern Leaf Blight']
grape_classes=['Black Rot', 'Esca', 'Healthy', 'Leaf Blight']
peach_classes=['Bacterial Spot', 'Healthy']
pepper_classes=['Bacterial Spot', 'Healthy']
potato_classes=['Early Blight', 'Healthy', 'Late Blight']
strawberry_classes=['Healthy', 'Leaf Scorch']
tomato_classes=['Bacterial Spot','Early Blight','Healthy','Late Blight']

# %% [markdown]
# ## *Loading Our Model*

# %%
apple_model=load_model('../models/apple_model.h5')
cherry_model=load_model('../models/cherry_model.h5')
corn_model=load_model('../models/corn_model.h5')
grape_model=load_model('../models/grape_model.h5')
peach_model=load_model('../models/peach_model.h5')
pepper_model=load_model('../models/pepper_model.h5')
potato_model=load_model('../models/potato_model.h5')
strawberry_model=load_model('../models/strawberry_model.h5')
tomato_model=load_model('../models/tomato_model.h5')

# %% [markdown]
# ## *Testing Our Models*

# %% [markdown]
# *Apple Model Testing*

# %%
image=load_img('../Dataset/test/AppleScab1.JPG')
image_array=img_to_array(image)
expanded_image=np.expand_dims(image_array,axis=0)

pred=apple_model.predict(expanded_image,verbose=0)
result=apple_classes[np.argmax(pred[0])]
print(result)
plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
# Apple Scab

# %% [markdown]
# *Cherry Model Testing*

# %%
image=load_img('../Dataset/test/CherryHealthy.JPG')
image_array=img_to_array(image)
expanded_image=np.expand_dims(image_array,axis=0)

pred=cherry_model.predict(expanded_image,verbose=0)
result=cherry_classes[np.argmax(pred[0])]
print(result)
plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
# Healthy

# %% [markdown]
# *Corn Model Testing*

# %%
image=load_img('../Dataset/test/CornCommonRust2.JPG')
image_array=img_to_array(image)
expanded_image=np.expand_dims(image_array,axis=0)

pred=corn_model.predict(expanded_image,verbose=0)
result=corn_classes[np.argmax(pred[0])]
print(result)
plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
# Common Rust

# %% [markdown]
# *Grape Model Testing*

# %%
image=load_img('../Dataset/test/GrapeEsca.JPG')
image_array=img_to_array(image)
expanded_image=np.expand_dims(image_array,axis=0)

pred=grape_model.predict(expanded_image,verbose=0)
result=grape_classes[np.argmax(pred[0])]
print(result)
plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
# Esca

# %% [markdown]
# *Peach Model Testing*

# %%
image=load_img('../Dataset/test/PeachBacterialSpot.JPG')
image_array=img_to_array(image)
expanded_image=np.expand_dims(image_array,axis=0)

pred=peach_model.predict(expanded_image,verbose=0)
result=peach_classes[np.argmax(pred[0])]
print(result)
plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002010810E2A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Bacterial Spot

# %% [markdown]
# *Pepper Model Testing*

# %%
image=load_img('../Dataset/test/PepperBacterialSpot.JPG')
image_array=img_to_array(image)
expanded_image=np.expand_dims(image_array,axis=0)

pred=pepper_model.predict(expanded_image,verbose=0)
result=pepper_classes[np.argmax(pred[0])]
print(result)
plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000201137379C0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Bacterial Spot

# %% [markdown]
# *Potato Model Testing*

# %%
image=load_img('../Dataset/test/PotatoHealthy2.JPG')
image_array=img_to_array(image)
expanded_image=np.expand_dims(image_array,axis=0)

pred=potato_model.predict(expanded_image,verbose=0)
result=potato_classes[np.argmax(pred[0])]
print(result)
plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
# Healthy

# %% [markdown]
# *Strawberry Model Testing*

# %%
image=load_img('../Dataset/test/StrawberryLeafScorch.JPG')
image_array=img_to_array(image)
expanded_image=np.expand_dims(image_array,axis=0)

pred=strawberry_model.predict(expanded_image,verbose=0)
result=strawberry_classes[np.argmax(pred[0])]
print(result)
plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
# Leaf Scorch

# %%
image=load_img('../Dataset/test/TomatoEarlyBlight5.JPG')
image_array=img_to_array(image)
expanded_image=np.expand_dims(image_array,axis=0)

pred=tomato_model.predict(expanded_image,verbose=0)
result=tomato_classes[np.argmax(pred[0])]
print(result)
plt.imshow(image)
plt.axis('off')
plt.show()
# Out:
# Early Blight
